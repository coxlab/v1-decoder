# %%
import os
from datetime import datetime
import h5py
import numpy as np
import pandas as pd
from data_helpers import format_timeseries
# from tempConv import tempConvDecoder

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
conf = {
    'bs' : 256,
    'eps' : 1,
    'lr' : 0.0005,
    'kernel' : 2,
    'nb_filter' : 5,
    'window' : 60,
    'offset' : 10,
    'regressor' : True,
    'pyramidal' : True,
    'resample_data' : False,
    'sample_size' : 40000,
    'run_id' : datetime.now(),
    'verbose' : False,
    'key' : ['absolute pitch'],
    'dataset' : None
}

# %%
path = 'datasets/GRat31'
X_train, X_test, y_train, y_test = format_timeseries(
    path, 
    conf['window'],
    conf['offset'],
    (0,12,1), 
    (7,8),
    resample_data=conf['resample_data'],
    sample_size=conf['sample_size'],
    regressor=conf['regressor']
)

dataset = {
    'train' : (X_train, y_train),
    'test' : (X_test, y_test)
}

conf['dataset'] = dataset
# Out:
# ['636429913515267697.hdf5', '636428029026710180.hdf5', '636430663717571697.hdf5', '636427282621202061.hdf5', '636431765535543697.hdf5', '636438658377315948.hdf5', '636439164041965948.hdf5', '636428953768193973.hdf5']

# %%
stats = []

# %%
TCD = tempConvDecoder(**conf)
TCD.fit()
R2s,rs = TCD.determine_fit()
stats.append([R2s, rs])
# Out:
# WARNING (theano.gof.cmodule): ModuleCache.refresh() Found key without dll in cache, deleting it. /n/home07/dapello/.theano/compiledir_Linux-3.10-el7.x86_64-x86_64-with-centos-7.2.1511-Core-x86_64-3.6.0-64/tmp1dg9xnrw/key.pkl
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '11761' (I am process '13265')
# Train on 394453 samples, validate on 98610 samples
# Epoch 1/1
#  - ETA: 1s - loss: 32.7669 - mean_squared_error: 1760.7074

# %%
print(stats)

# %%
TCD.model.evaluate(TCD.X_test,TCD.y_test)
# Out:
# 24608/24913 [============================>.] - ETA: 0s
# [0.52790511442393295, 0.74992975554931163]

# %%
path = 'datasets/GRat31'
X_val, y_val = format_timeseries(
    path, 
    conf['window'],
    conf['offset'],
    (0,12,1), 
    (7,8),
    resample_data=conf['resample_data'],
    sample_size=conf['sample_size'],
    regressor=conf['regressor'],
    all_test=True
)

X_val.shape
# Out:
# ['636429913515267697.hdf5', '636428029026710180.hdf5', '636430663717571697.hdf5', '636427282621202061.hdf5', '636431765535543697.hdf5', '636438658377315948.hdf5', '636439164041965948.hdf5', '636428953768193973.hdf5']
# (493063, 60, 12)

# %%
dataset['train'][0].shape
# Out:
# (394453, 60, 12)
